# %% [markdown]
# # Kreslení v Pythonu
#
# budeme používat knihovnu Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Rychlé kreslení

# %%
x = np.linspace(0, 2*np.pi)
fx = np.sin(x)
plt.plot(x, fx)

# %% [markdown]
# # Jednoduchý příklad
# ---
# který není úplně jednoduchý
# nejprve pojmy figure, axes, axis
# jde to i jednodušeji, ale takhel se nám budou lépe kreslit složitější výstupy

# %%
fig = plt.figure()   # prazdny obrazek
fig, ax = plt.subplots()  # jedny axes v obrazku, ale lze zadat i mrizku plt.subplots(2, 2)
ax.plot(x, fx)  # vykresleni bodu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/patrikludvik/Documents/MojeProjekty/skolaAI/skolaAI/lekce2/python-plotting.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/Users/patrikludvik/Documents/MojeProjekty/skolaAI/skolaAI/lekce2/python-plotting.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> fig = plt.figure()   # prazdny obrazek
#       <a href='vscode-notebook-cell:/Users/patrikludvik/Documents/MojeProjekty/skolaAI/skolaAI/lekce2/python-plotting.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> fig, ax = plt.subplots(2,2)  # jedny axes v obrazku, ale lze zadat i mrizku plt.subplots(2, 2)
# ----> <a href='vscode-notebook-cell:/Users/patrikludvik/Documents/MojeProjekty/skolaAI/skolaAI/lekce2/python-plotting.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> ax.plot(x, fx)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# ## Stylování
# ---

# %% [markdown]
# ### Čáry

# %%
x = np.linspace(0, 2*np.pi)
fx = np.sin(x)
gx = np.cos(x)
fig = plt.figure()   
fig, ax = plt.subplots()  
ax.plot(x, fx, lw=3, ls="--") # ls = linestyle, lw = linewidth
ax.plot(x, gx, lw=5, ls=":")

# %% [markdown]
# ### Barvičky
# [dokumentace barvy](https://matplotlib.org/stable/tutorials/colors/colors.html)

# %%
fig = plt.figure()   
fig, ax = plt.subplots()  
ax.plot(x, fx, color="coral") 
ax.plot(x, gx, color="olive")

# %% [markdown]
# ### Markery

# %%
x = np.arange(12)
y = np.exp(x)
fig = plt.figure()   
fig, ax = plt.subplots()
ax.plot(x, y, marker="o", ls="-")   # stejne jako ax.plot(x, y, "o-") :)

# %% [markdown]
# ## Scatter
# ----

# %%
from numpy import random  

x = random.rand(100)
y = random.rand(100)

fig = plt.figure()   
fig, ax = plt.subplots()  
ax.scatter(x, y, s=50, fc="blue", ec="k")   # s je velikost, fc=facecolor, ec=edgecolor

# %%
x = random.rand(40)
y = random.rand(40)

fig = plt.figure()   
fig, ax = plt.subplots() 

ax.set_aspect("equal")   # <-------- čtvercové souřadnice


ax.scatter(x, y, s=100, fc="blue", ec="k")   # s je velikost, fc=facecolor, ec=edgecolor

# %% [markdown]
# ## Histogram
# ---

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots()

ax.hist(x, 20) # 20 bins
# Out:
# (array([  12.,   20.,   59.,  147.,  283.,  527.,  871., 1173., 1407.,
#         1439., 1387., 1036.,  755.,  465.,  245.,  107.,   45.,   14.,
#            4.,    4.]),
#  array([ 62.8970067 ,  68.47176892,  74.04653115,  79.62129337,
#          85.1960556 ,  90.77081782,  96.34558005, 101.92034227,
#         107.4951045 , 113.06986673, 118.64462895, 124.21939118,
#         129.7941534 , 135.36891563, 140.94367785, 146.51844008,
#         152.0932023 , 157.66796453, 163.24272676, 168.81748898,
#         174.39225121]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Koláčový graf
# ---

# %%
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1i%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Heatmapa
# ---

# %%
data = np.random.random(( 12 , 5 ))
plt.imshow( data , cmap = 'autumn')

# %% [markdown]
# ## Sloupcový graf
# ---

# %%
fig, ax = plt.subplots()
jazyky = ['C', 'C++', 'Java', 'Python', 'PHP']
profici = [23,17,35,29,12]
ax.bar(jazyky, profici)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Popisky
# ---

# %%
x = np.linspace(0, 2*np.pi)
fx = np.sin(x)
gx = np.cos(x)

fig = plt.figure()   
fig, ax = plt.subplots()  
ax.plot(x, fx, color="coral", label="SIN") 
ax.plot(x, gx, color="olive", label="COS")
ax.legend()  # vyvolání legenda

# %% [markdown]
# ### Popisky os a obrázku

# %%
fig = plt.figure()   
fig, ax = plt.subplots()  
ax.plot(x, fx, color="coral") 
ax.plot(x, gx, color="olive")
ax.set_xlabel("osa x")
ax.set_ylabel("osa y")
ax.set_title("Funkce sin a cos")
# Out:
# Text(0.5, 1.0, 'Funkce sin a cos')

# %% [markdown]
# ### Nastavení os

# %%
x = np.linspace(0, 8*np.pi, 100)
fx = np.sin(x)

fig, ax = plt.subplots()  
ax.plot(x, fx)
ax.axis([0, 40, 0, 1])
# Out:
# (0.0, 40.0, 0.0, 1.0)

# %% [markdown]
# ### Text

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots()

ax.hist(x, 20) # 20 bins
ax.text(60, 1200, r"$\mu = 115, \sigma = 15$") # klidne LaTeX v $...$,  r znaci raw string
# Out:
# Text(60, 1200, '$\\mu = 115, \\sigma = 15$')
